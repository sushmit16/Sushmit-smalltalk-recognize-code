# %%
from nltk.tokenize import word_tokenize
from nltk.corpus import stopwords 
from nltk.tokenize import word_tokenize

# %%
l3=["Who are you?","How old are you?","You're annoying.","Answer my question.","You're bad.",
"Can you get smarter?","You're beautiful.","What's your birth date?","You're boring.","Who is your boss?","Are you busy?","Can you help me?","You're a chatbot.","You're a chatbot.","You're crazy.","You're fired.","You are funny.","You are good.","Are you happy?","Do you have a hobby?","Are you hungry?","Will you marry me?","Are we friends?","Where do you work?","Where are you from?","Are you ready?","Are you real?","Where do you live?","You're right.","Are you sure?","Talk to me.","Are you there?","That's bad.","Great!","No problem.","Thank you!","You're welcome","Well done","Bye-bye!","Good evening!","Good morning!","Good night!"," Hello!","How are you?","Nice to meet you!","Nice to see you!","Nice to talk to you!","What's up?","Ha ha ha!","Wow!","I'm very angry right now."," I'm back!","I am bored.","I am busy.","I can't sleep.","I don't want to talk.","I'm so excited.","I'm going to bed","I'm good.","I'm happy","Today is my birthday.",
"I'm kidding.","I'm so lonely","What do I look like?","I love you"," I miss you","I need some advice.","i'm sad","i'm sleepy",
"I'm just testing you.","i'm tired","i'm waiting",
"I'd like to see you again.",
"I just want to talk.","i'll be back","Hold on","give me a hug!","I don't care.","sorry","what do you mean?","you're wrong"]
s = " ".join(l3)

s1=s.lower()
print(s1)
# Out:
# who are you? how old are you? you're annoying. answer my question. you're bad. can you get smarter? you're beautiful. what's your birth date? you're boring. who is your boss? are you busy? can you help me? you're a chatbot. you're a chatbot. you're crazy. you're fired. you are funny. you are good. are you happy? do you have a hobby? are you hungry? will you marry me? are we friends? where do you work? where are you from? are you ready? are you real? where do you live? you're right. are you sure? talk to me. are you there? that's bad. great! no problem. thank you! you're welcome well done bye-bye! good evening! good morning! good night!  hello! how are you? nice to meet you! nice to see you! nice to talk to you! what's up? ha ha ha! wow! i'm very angry right now.  i'm back! i am bored. i am busy. i can't sleep. i don't want to talk. i'm so excited. i'm going to bed i'm good. i'm happy today is my birthday. i'm kidding. i'm so lonely what do i look like? i love you  i miss you i need some advice. i'm sad i'm sleepy i'm just testing you. i'm tired i'm waiting i'd like to see you again. i just want to talk. i'll be back hold on give me a hug! i don't care. sorry what do you mean? you're wrong

# %%
tokenize = word_tokenize(s1)
tokenize
# Out:
# ['who',
#  'are',
#  'you',
#  '?',
#  'how',
#  'old',
#  'are',
#  'you',
#  '?',
#  'you',
#  "'re",
#  'annoying',
#  '.',
#  'answer',
#  'my',
#  'question',
#  '.',
#  'you',
#  "'re",
#  'bad',
#  '.',
#  'can',
#  'you',
#  'get',
#  'smarter',
#  '?',
#  'you',
#  "'re",
#  'beautiful',
#  '.',
#  'what',
#  "'s",
#  'your',
#  'birth',
#  'date',
#  '?',
#  'you',
#  "'re",
#  'boring',
#  '.',
#  'who',
#  'is',
#  'your',
#  'boss',
#  '?',
#  'are',
#  'you',
#  'busy',
#  '?',
#  'can',
#  'you',
#  'help',
#  'me',
#  '?',
#  'you',
#  "'re",
#  'a',
#  'chatbot',
#  '.',
#  'you',
#  "'re",
#  'a',
#  'chatbot',
#  '.',
#  'you',
#  "'re",
#  'crazy',
#  '.',
#  'you',
#  "'re",
#  'fired',
#  '.',
#  'you',
#  'are',
#  'funny',
#  '.',
#  'you',
#  'are',
#  'good',
#  '.',
#  'are',
#  'you',
#  'happy',
#  '?',
#  'do',
#  'you',
#  'have',
#  'a',
#  'hobby',
#  '?',
#  'are',
#  'you',
#  'hungry',
#  '?',
#  'will',
#  'you',
#  'marry',
#  'me',
#  '?',
#  'are',
#  'we',
#  'friends',
#  '?',
#  'where',
#  'do',
#  'you',
#  'work',
#  '?',
#  'where',
#  'are',
#  'you',
#  'from',
#  '?',
#  'are',
#  'you',
#  'ready',
#  '?',
#  'are',
#  'you',
#  'real',
#  '?',
#  'where',
#  'do',
#  'you',
#  'live',
#  '?',
#  'you',
#  "'re",
#  'right',
#  '.',
#  'are',
#  'you',
#  'sure',
#  '?',
#  'talk',
#  'to',
#  'me',
#  '.',
#  'are',
#  'you',
#  'there',
#  '?',
#  'that',
#  "'s",
#  'bad',
#  '.',
#  'great',
#  '!',
#  'no',
#  'problem',
#  '.',
#  'thank',
#  'you',
#  '!',
#  'you',
#  "'re",
#  'welcome',
#  'well',
#  'done',
#  'bye-bye',
#  '!',
#  'good',
#  'evening',
#  '!',
#  'good',
#  'morning',
#  '!',
#  'good',
#  'night',
#  '!',
#  'hello',
#  '!',
#  'how',
#  'are',
#  'you',
#  '?',
#  'nice',
#  'to',
#  'meet',
#  'you',
#  '!',
#  'nice',
#  'to',
#  'see',
#  'you',
#  '!',
#  'nice',
#  'to',
#  'talk',
#  'to',
#  'you',
#  '!',
#  'what',
#  "'s",
#  'up',
#  '?',
#  'ha',
#  'ha',
#  'ha',
#  '!',
#  'wow',
#  '!',
#  'i',
#  "'m",
#  'very',
#  'angry',
#  'right',
#  'now',
#  '.',
#  'i',
#  "'m",
#  'back',
#  '!',
#  'i',
#  'am',
#  'bored',
#  '.',
#  'i',
#  'am',
#  'busy',
#  '.',
#  'i',
#  'ca',
#  "n't",
#  'sleep',
#  '.',
#  'i',
#  'do',
#  "n't",
#  'want',
#  'to',
#  'talk',
#  '.',
#  'i',
#  "'m",
#  'so',
#  'excited',
#  '.',
#  'i',
#  "'m",
#  'going',
#  'to',
#  'bed',
#  'i',
#  "'m",
#  'good',
#  '.',
#  'i',
#  "'m",
#  'happy',
#  'today',
#  'is',
#  'my',
#  'birthday',
#  '.',
#  'i',
#  "'m",
#  'kidding',
#  '.',
#  'i',
#  "'m",
#  'so',
#  'lonely',
#  'what',
#  'do',
#  'i',
#  'look',
#  'like',
#  '?',
#  'i',
#  'love',
#  'you',
#  'i',
#  'miss',
#  'you',
#  'i',
#  'need',
#  'some',
#  'advice',
#  '.',
#  'i',
#  "'m",
#  'sad',
#  'i',
#  "'m",
#  'sleepy',
#  'i',
#  "'m",
#  'just',
#  'testing',
#  'you',
#  '.',
#  'i',
#  "'m",
#  'tired',
#  'i',
#  "'m",
#  'waiting',
#  'i',
#  "'d",
#  'like',
#  'to',
#  'see',
#  'you',
#  'again',
#  '.',
#  'i',
#  'just',
#  'want',
#  'to',
#  'talk',
#  '.',
#  'i',
#  "'ll",
#  'be',
#  'back',
#  'hold',
#  'on',
#  'give',
#  'me',
#  'a',
#  'hug',
#  '!',
#  'i',
#  'do',
#  "n't",
#  'care',
#  '.',
#  'sorry',
#  'what',
#  'do',
#  'you',
#  'mean',
#  '?',
#  'you',
#  "'re",
#  'wrong']

# %%
#stop_words = set(stopwords.words('english'))

# %%
#stop_words

# %%
len(tokenize)
# Out:
# 337

# %%
st=set(tokenize)
l=list(st)
s2=" ".join(l)
punctuations = '''!()-[]{};:'"\,<>./?@#$%^&*_~'''
st1 = ""
for char in s2:
    if char not in punctuations:
        st1 = st1 + char
print(st1)
# Out:
# lonely bored real excited who answer nt no advice boss funny back am hug welcome love what see i thank byebye up morning hungry have ll sorry hobby  get birthday some going done wrong question do miss tired talk happy to just on friends you hello very wow well sure beautiful where care now need bad sad fired me old angry how ha live s d can today right  look hold give bed like sleepy mean ca boring birth want we is nice waiting help great date smarter that evening  work from re night be busy annoying m crazy testing meet ready good your are kidding so sleep marry chatbot will my there again problem a

# %%
t = word_tokenize(st1)
t
# Out:
# ['lonely',
#  'bored',
#  'real',
#  'excited',
#  'who',
#  'answer',
#  'nt',
#  'no',
#  'advice',
#  'boss',
#  'funny',
#  'back',
#  'am',
#  'hug',
#  'welcome',
#  'love',
#  'what',
#  'see',
#  'i',
#  'thank',
#  'byebye',
#  'up',
#  'morning',
#  'hungry',
#  'have',
#  'll',
#  'sorry',
#  'hobby',
#  'get',
#  'birthday',
#  'some',
#  'going',
#  'done',
#  'wrong',
#  'question',
#  'do',
#  'miss',
#  'tired',
#  'talk',
#  'happy',
#  'to',
#  'just',
#  'on',
#  'friends',
#  'you',
#  'hello',
#  'very',
#  'wow',
#  'well',
#  'sure',
#  'beautiful',
#  'where',
#  'care',
#  'now',
#  'need',
#  'bad',
#  'sad',
#  'fired',
#  'me',
#  'old',
#  'angry',
#  'how',
#  'ha',
#  'live',
#  's',
#  'd',
#  'can',
#  'today',
#  'right',
#  'look',
#  'hold',
#  'give',
#  'bed',
#  'like',
#  'sleepy',
#  'mean',
#  'ca',
#  'boring',
#  'birth',
#  'want',
#  'we',
#  'is',
#  'nice',
#  'waiting',
#  'help',
#  'great',
#  'date',
#  'smarter',
#  'that',
#  'evening',
#  'work',
#  'from',
#  're',
#  'night',
#  'be',
#  'busy',
#  'annoying',
#  'm',
#  'crazy',
#  'testing',
#  'meet',
#  'ready',
#  'good',
#  'your',
#  'are',
#  'kidding',
#  'so',
#  'sleep',
#  'marry',
#  'chatbot',
#  'will',
#  'my',
#  'there',
#  'again',
#  'problem',
#  'a']

# %%
len(t)
# Out:
# 116

# %%
'''for i in stop_words:
    if i in t:
        t.remove(i)'''
# Out:
# 'for i in stop_words:\n    if i in t:\n        t.remove(i)'

# %%
len(t)
# Out:
# 116

# %%
t
# Out:
# ['lonely',
#  'bored',
#  'real',
#  'excited',
#  'who',
#  'answer',
#  'nt',
#  'no',
#  'advice',
#  'boss',
#  'funny',
#  'back',
#  'am',
#  'hug',
#  'welcome',
#  'love',
#  'what',
#  'see',
#  'i',
#  'thank',
#  'byebye',
#  'up',
#  'morning',
#  'hungry',
#  'have',
#  'll',
#  'sorry',
#  'hobby',
#  'get',
#  'birthday',
#  'some',
#  'going',
#  'done',
#  'wrong',
#  'question',
#  'do',
#  'miss',
#  'tired',
#  'talk',
#  'happy',
#  'to',
#  'just',
#  'on',
#  'friends',
#  'you',
#  'hello',
#  'very',
#  'wow',
#  'well',
#  'sure',
#  'beautiful',
#  'where',
#  'care',
#  'now',
#  'need',
#  'bad',
#  'sad',
#  'fired',
#  'me',
#  'old',
#  'angry',
#  'how',
#  'ha',
#  'live',
#  's',
#  'd',
#  'can',
#  'today',
#  'right',
#  'look',
#  'hold',
#  'give',
#  'bed',
#  'like',
#  'sleepy',
#  'mean',
#  'ca',
#  'boring',
#  'birth',
#  'want',
#  'we',
#  'is',
#  'nice',
#  'waiting',
#  'help',
#  'great',
#  'date',
#  'smarter',
#  'that',
#  'evening',
#  'work',
#  'from',
#  're',
#  'night',
#  'be',
#  'busy',
#  'annoying',
#  'm',
#  'crazy',
#  'testing',
#  'meet',
#  'ready',
#  'good',
#  'your',
#  'are',
#  'kidding',
#  'so',
#  'sleep',
#  'marry',
#  'chatbot',
#  'will',
#  'my',
#  'there',
#  'again',
#  'problem',
#  'a']

# %%
t
# Out:
# ['lonely',
#  'bored',
#  'real',
#  'excited',
#  'who',
#  'answer',
#  'nt',
#  'no',
#  'advice',
#  'boss',
#  'funny',
#  'back',
#  'am',
#  'hug',
#  'welcome',
#  'love',
#  'what',
#  'see',
#  'i',
#  'thank',
#  'byebye',
#  'up',
#  'morning',
#  'hungry',
#  'have',
#  'll',
#  'sorry',
#  'hobby',
#  'get',
#  'birthday',
#  'some',
#  'going',
#  'done',
#  'wrong',
#  'question',
#  'do',
#  'miss',
#  'tired',
#  'talk',
#  'happy',
#  'to',
#  'just',
#  'on',
#  'friends',
#  'you',
#  'hello',
#  'very',
#  'wow',
#  'well',
#  'sure',
#  'beautiful',
#  'where',
#  'care',
#  'now',
#  'need',
#  'bad',
#  'sad',
#  'fired',
#  'me',
#  'old',
#  'angry',
#  'how',
#  'ha',
#  'live',
#  's',
#  'd',
#  'can',
#  'today',
#  'right',
#  'look',
#  'hold',
#  'give',
#  'bed',
#  'like',
#  'sleepy',
#  'mean',
#  'ca',
#  'boring',
#  'birth',
#  'want',
#  'we',
#  'is',
#  'nice',
#  'waiting',
#  'help',
#  'great',
#  'date',
#  'smarter',
#  'that',
#  'evening',
#  'work',
#  'from',
#  're',
#  'night',
#  'be',
#  'busy',
#  'annoying',
#  'm',
#  'crazy',
#  'testing',
#  'meet',
#  'ready',
#  'good',
#  'your',
#  'are',
#  'kidding',
#  'so',
#  'sleep',
#  'marry',
#  'chatbot',
#  'will',
#  'my',
#  'there',
#  'again',
#  'problem',
#  'a']

# %%
#t.append('am')
#t.append('wow')
#t.append('great')
#t.append('feeling')
#t.append('hate')
from nltk.stem import PorterStemmer
porter = PorterStemmer()
stem=[]
for i in t:
    stem.append(porter.stem(i))
print(stem)
# Out:
# ['lone', 'bore', 'real', 'excit', 'who', 'answer', 'nt', 'no', 'advic', 'boss', 'funni', 'back', 'am', 'hug', 'welcom', 'love', 'what', 'see', 'i', 'thank', 'byeby', 'up', 'morn', 'hungri', 'have', 'll', 'sorri', 'hobbi', 'get', 'birthday', 'some', 'go', 'done', 'wrong', 'question', 'do', 'miss', 'tire', 'talk', 'happi', 'to', 'just', 'on', 'friend', 'you', 'hello', 'veri', 'wow', 'well', 'sure', 'beauti', 'where', 'care', 'now', 'need', 'bad', 'sad', 'fire', 'me', 'old', 'angri', 'how', 'ha', 'live', 's', 'd', 'can', 'today', 'right', 'look', 'hold', 'give', 'bed', 'like', 'sleepi', 'mean', 'ca', 'bore', 'birth', 'want', 'we', 'is', 'nice', 'wait', 'help', 'great', 'date', 'smarter', 'that', 'even', 'work', 'from', 're', 'night', 'be', 'busi', 'annoy', 'm', 'crazi', 'test', 'meet', 'readi', 'good', 'your', 'are', 'kid', 'so', 'sleep', 'marri', 'chatbot', 'will', 'my', 'there', 'again', 'problem', 'a']

# %%
#for user's input
n=input("Say Something  : ")
n1=n.lower()
n1t = word_tokenize(n1)
n2=set(n1t)
l1=list(n2)
ns=" ".join(l1)
nts=""
for char in ns:
    if char not in punctuations:
        nts = nts + char
token = word_tokenize(nts)
'''for i in stop_words:
    if i in token:
        token.remove(i)'''
nstem=[]
for i in token:
    nstem.append(porter.stem(i))
c=0
for i in nstem:
    if i not in stem:
        break
    else:
        c+=1
if c==len(nstem):
    print("Small Talk")
else:
    print("It is not small talk")
# Out:
# Say Something  : how you doing?
# Small Talk
